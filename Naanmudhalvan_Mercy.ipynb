# %%
# Mounting drive to google colab:


from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#READ THE DATASET

import pandas as pd
path="/content/drive/MyDrive/MR_DATA.csv"
df=pd.read_csv(path)
print(df.head())
# Out:
#           Car       Model  Volume  Weight  CO2
# 0      Toyoty        Aygo    1000     790   99
# 1  Mitsubishi  Space Star    1200    1160   95
# 2       Skoda      Citigo    1000     929   95
# 3        Fiat         500     900     865   90
# 4        Mini      Cooper    1500    1140  105

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Load the dataset
data = {
    'Car': ['Toyota', 'Mitsubishi', 'Skoda', 'Fiat', 'Mini'],
    'Model': ['Aygo', 'Space Star', 'Citigo', '500', 'Cooper'],
    'Volume': [1000, 1200, 1000, 900, 1500],
    'Weight': [790, 1160, 929, 865, 1140],
    'CO2': [99, 95, 95, 90, 105]
}

df = pd.DataFrame(data)

# Separate features and target
X = df[['Volume', 'Weight']]  # Using 'Volume' and 'Weight' as features
y = df['CO2']

# Normalize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv1D, MaxPooling1D, Flatten

# Load the dataset
data = {
    'Car': ['Toyota', 'Mitsubishi', 'Skoda', 'Fiat', 'Mini'],
    'Model': ['Aygo', 'Space Star', 'Citigo', '500', 'Cooper'],
    'Volume': [1000, 1200, 1000, 900, 1500],
    'Weight': [790, 1160, 929, 865, 1140],
    'CO2': [99, 95, 95, 90, 105]
}

df = pd.DataFrame(data)

# Separate features and target
X = df[['Volume', 'Weight']]  # Using 'Volume' and 'Weight' as features
y = df['CO2']

# Normalize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Build the CNN model
cnn_model = Sequential([
    Conv1D(32, 2, activation='relu', input_shape=(X_train.shape[1], 1)),
    MaxPooling1D(1),  # Adjusted max pooling parameters
    Flatten(),
    Dense(64, activation='relu'),
    Dense(1)  # Output layer for regression task
])

# Compile the model
cnn_model.compile(optimizer='adam', loss='mse', metrics=['mae'])

# Train the model
cnn_model.fit(X_train.reshape(-1, 2, 1), y_train, epochs=10, batch_size=32, validation_data=(X_test.reshape(-1, 2, 1), y_test))
# Out:
# Epoch 1/10
# 1/1 [==============================] - 1s 1s/step - loss: 9469.6113 - mae: 97.1583 - val_loss: 9006.5547 - val_mae: 94.9029
# Epoch 2/10
# 1/1 [==============================] - 0s 62ms/step - loss: 9464.8750 - mae: 97.1342 - val_loss: 9002.4531 - val_mae: 94.8813
# Epoch 3/10
# 1/1 [==============================] - 0s 43ms/step - loss: 9460.2002 - mae: 97.1105 - val_loss: 8998.1865 - val_mae: 94.8588
# Epoch 4/10
# 1/1 [==============================] - 0s 42ms/step - loss: 9455.4912 - mae: 97.0866 - val_loss: 8993.8350 - val_mae: 94.8358
# Epoch 5/10
# 1/1 [==============================] - 0s 43ms/step - loss: 9450.6777 - mae: 97.0622 - val_loss: 8989.3418 - val_mae: 94.8121
# Epoch 6/10
# 1/1 [==============================] - 0s 62ms/step - loss: 9445.9414 - mae: 97.0381 - val_loss: 8984.8623 - val_mae: 94.7885
# Epoch 7/10
# 1/1 [==============================] - 0s 60ms/step - loss: 9441.1484 - mae: 97.0137 - val_loss: 8980.4062 - val_mae: 94.7650
# Epoch 8/10
# 1/1 [==============================] - 0s 55ms/step - loss: 9436.2949 - mae: 96.9890 - val_loss: 8975.9014 - val_mae: 94.7412
# Epoch 9/10
# 1/1 [==============================] - 0s 59ms/step - loss: 9431.4551 - mae: 96.9644 - val_loss: 8971.3486 - val_mae: 94.7172
# Epoch 10/10
# 1/1 [==============================] - 0s 46ms/step - loss: 9426.5479 - mae: 96.9395 - val_loss: 8966.7432 - val_mae: 94.6929

# %%
from tensorflow.keras.layers import LSTM

# Build the RNN model
rnn_model = Sequential([
    LSTM(32, input_shape=(X_train.shape[1], 1)),
    Dense(64, activation='relu'),
    Dense(1)  # Output layer for regression task
])

# Compile the model
rnn_model.compile(optimizer='adam', loss='mse', metrics=['mae'])

# Train the model
rnn_model.fit(X_train.reshape(-1, 2, 1), y_train, epochs=10, batch_size=32, validation_data=(X_test.reshape(-1, 2, 1), y_test))
# Out:
# Epoch 1/10
# 1/1 [==============================] -